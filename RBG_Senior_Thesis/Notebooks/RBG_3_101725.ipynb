# %%
import sys
sys.path.append('/Users/kelly/koskella_lab')
from tools import *

# %%
df = pd.read_csv('/Users/kelly/Downloads/RBG_data/KH_RBG3_101725.csv')
df = clean_and_transpose(df, 31, 129)
df1 = df.copy()

# %%
plot_timeseries(df, 'Combined Growth Curve')

# %% [markdown]
# # Series:
# - 0 = no phage (only KB+phage buffer)
# - 1: 10^3 phage
# - 2: 10^5 phage
# - 3: 10^7 phage

# %%
plot_biol_rep(df, num_bio_rep=8, col_num=3)

# %%
pfu_values = [0, 1e3, 1e5, 1e7]
plot_dose_response(df1, pfu_values)
